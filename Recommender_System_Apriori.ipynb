# %% [markdown]
# <a href="https://colab.research.google.com/github/AmrElmowafy1977/AmrElmowafy1977/blob/main/Recommender_System_Apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Import The libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=a46dec9ca0d97d8b3fe70bf063d3ec78f035240c3c782187632186f9330254bf
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
store_data = pd.read_csv('/content/Market_Basket_Optimisation.csv')
store_data.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %%
from apyori import apriori

# %%
records = []  
for i in range(0, 7500):  
    records.append([str(store_data.values[i,j]) for j in range(0, 20)])

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, 
                            in_lift=3, min_length=2)  
association_results = list(association_rules)

# %%
print(len(association_results ))  

print(association_results [0])
# Out:
# 1287
# RelationRecord(items=frozenset({'mineral water'}), support=0.23826666666666665, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water'}), confidence=0.23826666666666665, lift=1.0)])

# %%
for item in association_results :

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    if len(items)>=2 :
         print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Streaming output truncated to the last 5000 lines.
# Rule: nan -> rice
# Support: 0.0188
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> salad
# Support: 0.0048
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> salmon
# Support: 0.0424
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> salt
# Support: 0.0092
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> sandwich
# Support: 0.004533333333333334
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> shallot
# Support: 0.007733333333333333
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> shampoo
# Support: 0.004933333333333333
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> shrimp
# Support: 0.07133333333333333
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> soda
# Support: 0.006266666666666667
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> soup
# Support: 0.05053333333333333
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> spaghetti
# Support: 0.17413333333333333
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> sparkling water
# Support: 0.006266666666666667
# Confidence: 1.0
# ...
